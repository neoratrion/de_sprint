# %% [markdown]
# ## Анализ логов
# **Общая задача:** создать скрипт для формирования витрины на основе логов web-сайта.
#
# **Подробное описание задачи:**
#
# Разработать скрипт формирования витрины следующего содержания:
# 1.      Суррогатный ключ устройства
#
# 2.      Название устройства
#
# 3.      Количество пользователей
#
# 4.      Доля пользователей данного устройства от общего числа пользователей.
#
# 5.      Количество совершенных действий для данного устройства
#
# 6.      Доля совершенных действий с данного устройства, относительно других устройств
#
# 7.      Список из 5 самых популярных браузеров, используемых на данном устройстве различными пользователями, с указанием доли использования для данного браузера относительно остальных браузеров.
#
# 8.      Количество ответов сервера отличных от 200 на данном устройстве
#
# 9.      Для каждого из ответов сервера, отличных от 200, сформировать поле, в котором будет содержаться количество ответов данного типа

# %%
pip install clickhouse_connect

# %%
pip install user_agents

# %%
import pandas as pd
from tqdm import tqdm
from user_agents import parse
import clickhouse_connect
import warnings
warnings.filterwarnings('ignore')

# %%
df_ch = pd.read_csv('./data/client_hostname.csv')
df_ch

# %%
# %%time

file = './data/access.log'
logs = pd.DataFrame()
with open(file) as fl:
    chunk_iter = pd.read_table(fl, chunksize=100000, engine='python', header=None, index_col=False, 
                               names=['ip', 'datetime', 'request', 'code_req', 'port', 'user_agent'], 
                               sep=" - - \[{1}(.+)\] \"(.*?)\" (\d+) (\d+) .+ \"(.{2,}?)\".*")
    for chunk in chunk_iter:
        chunk = chunk[chunk['code_req'] != 200]
        logs = pd.concat([logs,chunk])
logs
# Out:
# CPU times: user 1min 28s, sys: 1.13 s, total: 1min 29s
# Wall time: 1min 30s
#                      ip                    datetime  \
# 16        207.46.13.136  22/Jan/2019:03:56:19 +0330
# 39        66.249.66.194  22/Jan/2019:03:56:23 +0330
# 81          5.211.97.39  22/Jan/2019:03:56:31 +0330
# 94         54.36.148.87  22/Jan/2019:03:56:34 +0330
# 147       207.46.13.104  22/Jan/2019:03:56:46 +0330
# ...                 ...                         ...
# 10365121  37.129.59.160  26/Jan/2019:20:29:12 +0330
# 10365122   66.249.66.92  26/Jan/2019:20:29:12 +0330
# 10365130   5.127.220.71  26/Jan/2019:20:29:12 +0330
# 10365147  188.229.21.56  26/Jan/2019:20:29:13 +0330
# 10365148   5.127.220.71  26/Jan/2019:20:29:13 +0330
#
#                                                     request  code_req  \
# 16                              GET /product/14926 HTTP/1.1     404.0
# 39                              GET /product/81900 HTTP/1.1     404.0
# 81        HEAD /amp_preconnect_polyfill_404_or_other_err...     404.0
# 94        GET /filter/p65%2Cv1%7C%D9%86%D9%82%D8%B1%D9%8...     302.0
# 147           GET /browse/flute-keys/www.zanbil.ir HTTP/1.1     404.0
# ...                                                     ...       ...
# 10365121  GET /basket/add/62424?mobile=1&addedValues= HT...     302.0
# 10365122     GET /static/css/font/wyekan/font.woff HTTP/1.1     304.0
# 10365130  GET /apple-touch-icon-120x120-precomposed.png ...     404.0
# 10365147           GET /content/view/shoppingRules HTTP/1.1     302.0
# 10365148         GET /apple-touch-icon-120x120.png HTTP/1.1     404.0
#
#              port                                         user_agent
# 16        33617.0  Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# 39        32278.0  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 81            0.0  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# 94            0.0  Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...
# 147       33605.0  Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# ...           ...                                                ...
# 10365121      0.0  Mozilla/5.0 (Linux; Android 6.0.1; D6633 Build...
# 10365122      0.0  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 10365130  32426.0     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0
# 10365147      0.0  Mozilla/5.0 (Linux; Android 7.0; SM-N920C Buil...
# 10365148  32420.0     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0
#
# [785327 rows x 6 columns]

# %% [markdown]
# ______
# ### DATA QUALITY:

# %%
logs.isnull().sum()
# Out:
# ip            0
# datetime      2
# request       8
# code_req      2
# port          2
# user_agent    2
# dtype: int64

# %%
logs = logs.dropna()
print('Data is clean')
# Out:
# Data is clean

# %% [markdown]
# __________

# %%
logs = logs.astype({'code_req': int, 'port': int})

# %%
logs
# Out:
#                      ip                    datetime  \
# 16        207.46.13.136  22/Jan/2019:03:56:19 +0330
# 39        66.249.66.194  22/Jan/2019:03:56:23 +0330
# 81          5.211.97.39  22/Jan/2019:03:56:31 +0330
# 94         54.36.148.87  22/Jan/2019:03:56:34 +0330
# 147       207.46.13.104  22/Jan/2019:03:56:46 +0330
# ...                 ...                         ...
# 10365121  37.129.59.160  26/Jan/2019:20:29:12 +0330
# 10365122   66.249.66.92  26/Jan/2019:20:29:12 +0330
# 10365130   5.127.220.71  26/Jan/2019:20:29:12 +0330
# 10365147  188.229.21.56  26/Jan/2019:20:29:13 +0330
# 10365148   5.127.220.71  26/Jan/2019:20:29:13 +0330
#
#                                                     request  code_req   port  \
# 16                              GET /product/14926 HTTP/1.1       404  33617
# 39                              GET /product/81900 HTTP/1.1       404  32278
# 81        HEAD /amp_preconnect_polyfill_404_or_other_err...       404      0
# 94        GET /filter/p65%2Cv1%7C%D9%86%D9%82%D8%B1%D9%8...       302      0
# 147           GET /browse/flute-keys/www.zanbil.ir HTTP/1.1       404  33605
# ...                                                     ...       ...    ...
# 10365121  GET /basket/add/62424?mobile=1&addedValues= HT...       302      0
# 10365122     GET /static/css/font/wyekan/font.woff HTTP/1.1       304      0
# 10365130  GET /apple-touch-icon-120x120-precomposed.png ...       404  32426
# 10365147           GET /content/view/shoppingRules HTTP/1.1       302      0
# 10365148         GET /apple-touch-icon-120x120.png HTTP/1.1       404  32420
#
#                                                  user_agent
# 16        Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# 39        Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 81        Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
# 94        Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...
# 147       Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# ...                                                     ...
# 10365121  Mozilla/5.0 (Linux; Android 6.0.1; D6633 Build...
# 10365122  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 10365130     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0
# 10365147  Mozilla/5.0 (Linux; Android 7.0; SM-N920C Buil...
# 10365148     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0
#
# [785319 rows x 6 columns]

# %%
# %%time

logs['browser'] = logs.user_agent.apply(lambda x: parse(x).browser.family)
logs['device'] = logs.user_agent.apply(lambda x: parse(x).device.brand if parse(x).device.brand is not(None) else parse(x).os.family)
logs
# Out:
# CPU times: user 1min 14s, sys: 3.51 ms, total: 1min 14s
# Wall time: 1min 14s
#                      ip                    datetime  \
# 16        207.46.13.136  22/Jan/2019:03:56:19 +0330
# 39        66.249.66.194  22/Jan/2019:03:56:23 +0330
# 81          5.211.97.39  22/Jan/2019:03:56:31 +0330
# 94         54.36.148.87  22/Jan/2019:03:56:34 +0330
# 147       207.46.13.104  22/Jan/2019:03:56:46 +0330
# ...                 ...                         ...
# 10365121  37.129.59.160  26/Jan/2019:20:29:12 +0330
# 10365122   66.249.66.92  26/Jan/2019:20:29:12 +0330
# 10365130   5.127.220.71  26/Jan/2019:20:29:12 +0330
# 10365147  188.229.21.56  26/Jan/2019:20:29:13 +0330
# 10365148   5.127.220.71  26/Jan/2019:20:29:13 +0330
#
#                                                     request  code_req   port  \
# 16                              GET /product/14926 HTTP/1.1       404  33617
# 39                              GET /product/81900 HTTP/1.1       404  32278
# 81        HEAD /amp_preconnect_polyfill_404_or_other_err...       404      0
# 94        GET /filter/p65%2Cv1%7C%D9%86%D9%82%D8%B1%D9%8...       302      0
# 147           GET /browse/flute-keys/www.zanbil.ir HTTP/1.1       404  33605
# ...                                                     ...       ...    ...
# 10365121  GET /basket/add/62424?mobile=1&addedValues= HT...       302      0
# 10365122     GET /static/css/font/wyekan/font.woff HTTP/1.1       304      0
# 10365130  GET /apple-touch-icon-120x120-precomposed.png ...       404  32426
# 10365147           GET /content/view/shoppingRules HTTP/1.1       302      0
# 10365148         GET /apple-touch-icon-120x120.png HTTP/1.1       404  32420
#
#                                                  user_agent        browser  \
# 16        Mozilla/5.0 (compatible; bingbot/2.0; +http://...        bingbot
# 39        Mozilla/5.0 (compatible; Googlebot/2.1; +http:...      Googlebot
# 81        Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  Mobile Safari
# 94        Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...      AhrefsBot
# 147       Mozilla/5.0 (compatible; bingbot/2.0; +http://...        bingbot
# ...                                                     ...            ...
# 10365121  Mozilla/5.0 (Linux; Android 6.0.1; D6633 Build...  Chrome Mobile
# 10365122  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...      Googlebot
# 10365130     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0   MobileSafari
# 10365147  Mozilla/5.0 (Linux; Android 7.0; SM-N920C Buil...  Chrome Mobile
# 10365148     MobileSafari/604.1 CFNetwork/976 Darwin/18.2.0   MobileSafari
#
#            device
# 16         Spider
# 39         Spider
# 81          Apple
# 94         Spider
# 147        Spider
# ...           ...
# 10365121     Sony
# 10365122   Spider
# 10365130    Apple
# 10365147  Samsung
# 10365148    Apple
#
# [785319 rows x 8 columns]

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 785319 entries, 16 to 10365148
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ip          785319 non-null  object
#  1   datetime    785319 non-null  object
#  2   request     785319 non-null  object
#  3   code_req    785319 non-null  int64
#  4   port        785319 non-null  int64
#  5   user_agent  785319 non-null  object
#  6   browser     785319 non-null  object
#  7   device      785319 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 53.9+ MB

# %%
try:
    client = clickhouse_connect.get_client(host='localhost', username='default', password='')
    print('Connected to Clickhouse server')
except:
    print ('Can not connect to Clickhouse server')
    exit()
# Out:
# Connected to Clickhouse server

# %% [markdown]
# Создание БД

# %%
client.command('CREATE DATABASE IF NOT EXISTS logs')
client.command('CREATE TABLE IF NOT EXISTS logs.table (ip String, datetime String, request String, code_req Integer, port Integer, user_agent String, browser String, device String) ENGINE Memory')
# Out:
# ''

# %%
#client.command('DROP TABLE logs.table')
# Out:
# ''

# %%
client.insert('logs.table', logs, column_names=['ip', 'datetime', 'request', 'code_req', 'port', 'user_agent', 'browser', 'device'])

# %%
device_and_users_query = client.query('SELECT device, uniq(ip) AS count_users FROM logs.table GROUP BY device ORDER BY device').result_set
data_mart = pd.DataFrame(list(device_and_users_query), columns=['device_name', 'users_count'])

data_mart['percent_users'] = (data_mart['users_count'] / data_mart['users_count'].sum()) * 100

actions_query = client.query('SELECT device, count(request) AS c FROM logs.table GROUP BY device ORDER BY device').result_set
actions = pd.DataFrame(list(actions_query), columns=['device_name', 'actions_device_count'])
data_mart = data_mart.merge(actions)

data_mart['percent_actions'] = (data_mart['actions_device_count'] / data_mart['actions_device_count'].sum()) * 100

browsers_query = client.query('SELECT browser, count(*) AS c FROM logs.table GROUP BY browser ORDER BY c DESC LIMIT 6').result_set
browsers_dict = dict()
for device in data_mart.device_name:
    query = client.query("SELECT browser, count(*) AS c FROM logs.table WHERE device = '"+device+"' GROUP BY browser ORDER BY c DESC LIMIT 5").result_set
    query_dict = {}
    for y in range(len(query)):
        query_dict[query[y][0]] = query[y][1]
    browsers_dict[device] = str(query_dict)
browsers = pd.DataFrame.from_dict(browsers_dict, orient='index', columns=['top_browsers'])
browsers = browsers.reset_index()
browsers.columns = ['device_name', 'top_browsers']
data_mart = data_mart.merge(browsers)

count_codes_query = client.query('SELECT device, count(code_req) AS c FROM logs.table WHERE code_req != 200 GROUP BY device ORDER BY device').result_set
count_codes = pd.DataFrame(list(count_codes_query), columns=['device_name', 'count_code_not_200'])
data_mart = data_mart.merge(count_codes)

codes_query = client.query('SELECT device, groupArray(code_req) AS c FROM logs.table WHERE code_req != 200 GROUP BY device ORDER BY device').result_set
codes_list = list()
for i in range(len(codes_query)):
    codes_list.append((codes_query[i][0], str(dict(pd.Series(codes_query[i][1]).value_counts()))))
codes = pd.DataFrame(codes_list, columns=['device_name', 'count_code'])
data_mart = data_mart.merge(codes)

# %%
data_mart
# Out:
#                device_name  users_count  percent_users  actions_device_count  \
# 0                     Acer            2       0.003286                     8
# 1                  Alcatel           14       0.023000                   114
# 2                   Amazon            1       0.001643                     1
# 3                    Apple        10377      17.048087                 99326
# 4                   Archos            1       0.001643                     6
# 5                     Asus          337       0.553648                  1027
# 6               BlackBerry           14       0.023000                    68
# 7                Chrome OS            1       0.001643                     1
# 8                    Cubot            1       0.001643                     3
# 9                   Fedora            3       0.004929                    18
# 10                     Fly            3       0.004929                     4
# 11                 Generic         1252       2.056876                  7647
# 12         Generic_Android         1344       2.208021                  3979
# 13  Generic_Android_Tablet          868       1.426013                  1837
# 14                Gigabyte            1       0.001643                     1
# 15                  Google            4       0.006571                    17
# 16                      HP            2       0.003286                    16
# 17                     HTC          699       1.148368                  2373
# 18                  Huawei         5938       9.755376                 18721
# 19                 Hyundai            1       0.001643                     1
# 20                 Infinix            1       0.001643                     7
# 21                      LG         1445       2.373951                  4904
# 22                  Lenovo         1030       1.692159                  3662
# 23                   Linux          211       0.346646                  1699
# 24                  Mageia            1       0.001643                     1
# 25                Micromax           94       0.154430                   165
# 26               Microsoft           20       0.032857                   208
# 27                Motorola           24       0.039429                    67
# 28                   Nokia          351       0.576648                  1254
# 29                 OnePlus            9       0.014786                    24
# 30                    Oppo            6       0.009857                    17
# 31                   Other          756       1.242012                  7087
# 32                     POV            1       0.001643                     1
# 33               Prestigio           10       0.016429                    54
# 34                     RCA            1       0.001643                     1
# 35                 Samsung        17763      29.182342                 57106
# 36                 Solaris            1       0.001643                     1
# 37                    Sony          796       1.307726                  3015
# 38            SonyEricsson          189       0.310503                   927
# 39                  Spider         1140       1.872875                393644
# 40                   Tecno           25       0.041072                    73
# 41                Trekstor            1       0.001643                     1
# 42                  Ubuntu           83       0.136358                   483
# 43                 Windows        15536      25.523666                174242
# 44                  XiaoMi          491       0.806650                  1476
# 45                     ZTE           16       0.026286                    25
# 46                     iOS            2       0.003286                     3
# 47                    vivo            3       0.004929                     4
#
#     percent_actions                                       top_browsers  \
# 0          0.001019                        {'Chrome': 6, 'Android': 2}
# 1          0.014516  {'Android': 88, 'Chrome Mobile': 16, 'Chrome':...
# 2          0.000127                                 {'Amazon Silk': 1}
# 3         12.647854  {'MobileSafari': 55914, 'Mobile Safari': 26501...
# 4          0.000764                                     {'Android': 6}
# 5          0.130775  {'Chrome Mobile': 651, 'Chrome': 175, 'Chrome ...
# 6          0.008659                          {'BlackBerry WebKit': 68}
# 7          0.000127                                      {'Chrome': 1}
# 8          0.000382                               {'Chrome Mobile': 3}
# 9          0.002292                       {'Firefox': 15, 'Chrome': 3}
# 10         0.000509                 {'Android': 2, 'Chrome Mobile': 2}
# 11         0.973744  {'Firefox Mobile': 7577, 'Chrome Mobile': 36, ...
# 12         0.506673  {'Chrome Mobile': 3159, 'Chrome Mobile WebView...
# 13         0.233918  {'Chrome': 1726, 'Chrome Mobile WebView': 99, ...
# 14         0.000127                               {'Chrome Mobile': 1}
# 15         0.002165                              {'Chrome Mobile': 17}
# 16         0.002037                        {'Android': 9, 'Chrome': 7}
# 17         0.302170  {'Chrome Mobile': 1459, 'Android': 452, 'Chrom...
# 18         2.383872  {'Chrome Mobile': 10481, 'Android': 6603, 'Chr...
# 19         0.000127                                      {'Chrome': 1}
# 20         0.000891                               {'Chrome Mobile': 7}
# 21         0.624460  {'Chrome Mobile': 3986, 'Android': 483, 'Chrom...
# 22         0.466307  {'Chrome': 1749, 'Android': 1542, 'Chrome Mobi...
# 23         0.216345  {'Chrome': 1446, 'Samsung Internet': 69, 'Fire...
# 24         0.000127                                     {'Firefox': 1}
# 25         0.021011  {'Chrome': 143, 'Chrome Mobile WebView': 12, '...
# 26         0.026486                                 {'IE Mobile': 208}
# 27         0.008532  {'Chrome Mobile': 63, 'Android': 3, 'Chrome Mo...
# 28         0.159680  {'Chrome Mobile': 795, 'IE Mobile': 173, 'Edge...
# 29         0.003056                              {'Chrome Mobile': 24}
# 30         0.002165  {'Opera Mobile': 7, 'Chrome Mobile': 6, 'Andro...
# 31         0.902436  {'Other': 6807, 'Python Requests': 140, 'curl'...
# 32         0.000127                       {'Chrome Mobile WebView': 1}
# 33         0.006876                      {'Chrome': 29, 'Android': 25}
# 34         0.000127                                      {'Chrome': 1}
# 35         7.271695  {'Chrome Mobile': 27257, 'Samsung Internet': 1...
# 36         0.000127                                       {'Other': 1}
# 37         0.383920  {'Chrome Mobile': 2525, 'Android': 249, 'Chrom...
# 38         0.118041  {'Chrome Mobile': 519, 'Android': 364, 'UC Bro...
# 39        50.125363  {'Googlebot': 219188, 'Googlebot-Image': 11833...
# 40         0.009296  {'Chrome Mobile': 66, 'Chrome Mobile WebView': 7}
# 41         0.000127                       {'Chrome Mobile WebView': 1}
# 42         0.061504  {'Firefox': 463, 'Chromium': 18, 'Chrome': 1, ...
# 43        22.187417  {'Firefox': 106253, 'Chrome': 59650, 'IE': 496...
# 44         0.187949  {'Chrome Mobile': 1101, 'MiuiBrowser': 269, 'U...
# 45         0.003183  {'Chrome Mobile': 22, 'Chrome Mobile WebView':...
# 46         0.000382                                       {'Other': 3}
# 47         0.000509                               {'Chrome Mobile': 4}
#
#     count_code_not_200                                         count_code
# 0                    8                                   {302: 7, 404: 1}
# 1                  114  {404: 62, 302: 33, 499: 8, 403: 5, 500: 3, 304...
# 2                    1                                           {301: 1}
# 3                99326  {404: 69205, 302: 20520, 499: 3850, 301: 2879,...
# 4                    6                                   {404: 5, 302: 1}
# 5                 1027  {302: 527, 304: 180, 499: 137, 404: 86, 403: 7...
# 6                   68         {304: 35, 404: 21, 302: 6, 499: 3, 301: 3}
# 7                    1                                           {301: 1}
# 8                    3                                   {302: 2, 499: 1}
# 9                   18                           {302: 8, 499: 8, 301: 2}
# 10                   4                           {499: 2, 302: 1, 404: 1}
# 11                7647  {304: 3448, 302: 2767, 499: 1112, 301: 113, 40...
# 12                3979  {302: 1970, 499: 830, 304: 609, 404: 309, 403:...
# 13                1837  {302: 1297, 499: 248, 304: 246, 403: 21, 301: ...
# 14                   1                                           {302: 1}
# 15                  17                                  {302: 15, 499: 2}
# 16                  16                   {404: 8, 304: 5, 302: 2, 499: 1}
# 17                2373  {302: 996, 499: 478, 404: 387, 304: 347, 403: ...
# 18               18721  {302: 6421, 404: 6094, 499: 3333, 304: 1732, 4...
# 19                   1                                           {302: 1}
# 20                   7                                   {499: 6, 302: 1}
# 21                4904  {302: 2559, 499: 946, 304: 700, 403: 335, 404:...
# 22                3662  {302: 1626, 304: 1388, 499: 280, 404: 266, 403...
# 23                1699  {302: 741, 301: 631, 304: 119, 499: 113, 404: ...
# 24                   1                                           {301: 1}
# 25                 165  {302: 123, 499: 15, 403: 12, 304: 11, 301: 2, ...
# 26                 208               {404: 151, 302: 38, 499: 15, 304: 4}
# 27                  67         {302: 32, 499: 26, 304: 6, 404: 2, 403: 1}
# 28                1254  {302: 518, 304: 321, 499: 204, 404: 170, 301: ...
# 29                  24                           {302: 9, 499: 8, 304: 7}
# 30                  17                   {304: 7, 499: 5, 404: 4, 302: 1}
# 31                7087  {304: 3180, 301: 1779, 302: 1193, 400: 532, 40...
# 32                   1                                           {302: 1}
# 33                  54          {404: 38, 302: 9, 499: 4, 304: 2, 301: 1}
# 34                   1                                           {302: 1}
# 35               57106  {302: 24962, 499: 12167, 304: 9366, 404: 6670,...
# 36                   1                                           {301: 1}
# 37                3015  {404: 1112, 302: 932, 304: 416, 499: 399, 403:...
# 38                 927  {404: 499, 499: 208, 302: 160, 304: 37, 301: 1...
# 39              393644  {304: 283460, 302: 52357, 301: 41732, 404: 139...
# 40                  73  {302: 36, 301: 11, 403: 9, 499: 8, 304: 7, 504...
# 41                   1                                           {302: 1}
# 42                 483  {302: 276, 301: 170, 499: 19, 404: 11, 304: 4,...
# 43              174242  {302: 78883, 304: 31936, 499: 25106, 301: 1798...
# 44                1476  {302: 777, 304: 286, 499: 279, 403: 70, 301: 3...
# 45                  25                  {302: 18, 499: 4, 301: 2, 404: 1}
# 46                   3                                   {302: 2, 499: 1}
# 47                   4                                           {302: 4}

# %%
data_mart.to_csv('./data_mart.csv')
