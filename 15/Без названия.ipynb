# %%
pip install country_converter
# Out:
# Requirement already satisfied: country_converter in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (0.7.7)
# Requirement already satisfied: pandas>=1.0 in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (from country_converter) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (from pandas>=1.0->country_converter) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (from pandas>=1.0->country_converter) (1.18.3)
# Requirement already satisfied: six>=1.5 in /home/dima/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->country_converter) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import country_converter as coco
import warnings
warnings.filterwarnings('ignore')

# %%
Сгруппируйте вакансии по направлениями (DS, DE, Software Engenering, etc.)
Какая средняя и медианная зарплата по группам вакансий?
Какая средняя и медианная зарплата по каждому региону?
Какая самая высокооплачиваемая из групп вакансий, исходя из их средних зарплат?
Какое процентное соотношение каждого региона по вакансиям от всех вакансий?
Какая корреляция уровня опыта от зарплаты?
Сколько должностей в наборе данных?
Какие 10 наиболее часто встречающихся должностей?
# Out:
#   File "/tmp/ipykernel_225678/4176860217.py", line 1
#     Сгруппируйте вакансии по направлениями (DS, DE, Software Engenering, etc.)
#                         ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('archive.zip', index_col=0)  
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
df.drop(['salary','salary_currency'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary_in_usd       607 non-null    int64
#  5   employee_residence  607 non-null    object
#  6   remote_ratio        607 non-null    int64
#  7   company_location    607 non-null    object
#  8   company_size        607 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 47.4+ KB

# %%
df.describe(include='all')
# Out:
#           work_year experience_level employment_type       job_title  \
# count    607.000000              607             607             607
# unique          NaN                4               4              50
# top             NaN               SE              FT  Data Scientist
# freq            NaN              280             588             143
# mean    2021.405272              NaN             NaN             NaN
# std        0.692133              NaN             NaN             NaN
# min     2020.000000              NaN             NaN             NaN
# 25%     2021.000000              NaN             NaN             NaN
# 50%     2022.000000              NaN             NaN             NaN
# 75%     2022.000000              NaN             NaN             NaN
# max     2022.000000              NaN             NaN             NaN
#
#         salary_in_usd employee_residence  remote_ratio company_location  \
# count      607.000000                607     607.00000              607
# unique            NaN                 57           NaN               50
# top               NaN                 US           NaN               US
# freq              NaN                332           NaN              355
# mean    112297.869852                NaN      70.92257              NaN
# std      70957.259411                NaN      40.70913              NaN
# min       2859.000000                NaN       0.00000              NaN
# 25%      62726.000000                NaN      50.00000              NaN
# 50%     101570.000000                NaN     100.00000              NaN
# 75%     150000.000000                NaN     100.00000              NaN
# max     600000.000000                NaN     100.00000              NaN
#
#        company_size
# count           607
# unique            3
# top               M
# freq            326
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
df.duplicated().mean()
# Out:
# 0.06919275123558484

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 0            79833                 DE             0               DE
# 1           260000                 JP             0               JP
# 2           109024                 GB            50               GB
# 3            20000                 HN             0               HN
# 4           150000                 US            50               US
# ..             ...                ...           ...              ...
# 602         154000                 US           100               US
# 603         126000                 US           100               US
# 604         129000                 US             0               US
# 605         150000                 US           100               US
# 606         200000                 IN           100               US
#
#     company_size
# 0              L
# 1              S
# 2              M
# 3              S
# 4              L
# ..           ...
# 602            M
# 603            M
# 604            M
# 605            M
# 606            L
#
# [565 rows x 9 columns]

# %%
df.isna().mean()
# Out:
# work_year             0.0
# experience_level      0.0
# employment_type       0.0
# job_title             0.0
# salary_in_usd         0.0
# employee_residence    0.0
# remote_ratio          0.0
# company_location      0.0
# company_size          0.0
# dtype: float64

# %%
df.groupby("job_title").agg({'salary':'count'}).sort_values('salary', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_225678/2206984601.py in <module>
# ----> 1 df.groupby("job_title").agg({'salary':'count'}).sort_values('salary', ascending=False)
#
# ~/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# ~/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ~/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     425             selection = obj._selection
#     426
# --> 427         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     428
#     429         if selected_obj.ndim == 1:
#
# ~/apps/anaconda/envs/praktikum_env_win_new/lib/python3.7/site-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     544             if len(cols) > 0:
#     545                 cols_sorted = list(safe_sort(list(cols)))
# --> 546                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     547
#     548         is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#
# KeyError: "Column(s) ['salary'] do not exist"

# %%
df.groupby("job_title").agg({'salary_in_usd':["mean", "median"]}).\
            sort_values(('salary_in_usd', 'mean'), ascending=False)
